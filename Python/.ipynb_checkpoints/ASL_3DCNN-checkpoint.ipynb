# %%
import tqdm
import random
import pathlib
import itertools
import collections
import re
import json
import shutil
import cv2
import numpy as np
import tensorflow as tf
import shutil
import math
import imageio
from tensorflow_docs.vis import embed
import keras
import matplotlib.pyplot as plt

import os
from os import listdir
from os.path import isfile, join
from pathlib import Path

# %%
#Grab all files and store them in a list
path = "C:\CSP400\CSP400_ASLToText\Data\wlasl-complete\sample_classes"
files = [os.path.join(root, name)
             for root, dirs, files in os.walk(path)
             for name in files]

print(len(files))
# Out:
# 5336

# %%
#Find the class of a video based of its full path
def Get_Class(filename):
    #print(filename)
    return filename.split("\\")[-2]

# %%
#Create a dict where dict[class,list of file names]
def Get_Class_Files(files):
    files_for_class = collections.defaultdict(list)
    for fname in files:
        class_name = Get_Class(fname)
        #print(class_name)
        files_for_class[class_name].append(fname)
    return files_for_class

# %%
#Create a dict where dict[class,list of file names] however only grab
#our max amount of files we want to use from that class
#typically will just be all files
def Select_Class_Subset(files_for_class, classes, files_per_class):
    files_subset = dict()

    for class_name in classes:
        class_files = files_for_class[class_name]
        files_subset[class_name] = class_files[:files_per_class]

    return files_subset

# %%
files_classes = Get_Class_Files(files)
classes = list(files_classes.keys())

NUM_CLASSES = len(classes)
FILES_PER_CLASS = 50


print('Num classes:', len(classes))
print('Num videos for class[0]:', len(files_classes[classes[0]]))
# Out:
# Num classes: 500
# Num videos for class[0]: 8

# %%
files_subset = Select_Class_Subset(files_classes, classes[:NUM_CLASSES], FILES_PER_CLASS)
list(files_subset.keys())
# Out:
# ['a',
#  'a lot',
#  'abdomen',
#  'able',
#  'about',
#  'above',
#  'accent',
#  'accept',
#  'accident',
#  'accomplish',
#  'accountant',
#  'across',
#  'act',
#  'action',
#  'active',
#  'activity',
#  'actor',
#  'adapt',
#  'add',
#  'address',
#  'adjective',
#  'adjust',
#  'admire',
#  'admit',
#  'adopt',
#  'adult',
#  'advanced',
#  'advantage',
#  'adverb',
#  'affect',
#  'afraid',
#  'africa',
#  'after',
#  'afternoon',
#  'again',
#  'against',
#  'age',
#  'agenda',
#  'ago',
#  'agree',
#  'agreement',
#  'ahead',
#  'aid',
#  'aim',
#  'airplane',
#  'alarm',
#  'alcohol',
#  'algebra',
#  'all',
#  'all day',
#  'allergy',
#  'alligator',
#  'allow',
#  'almost',
#  'alone',
#  'alphabet',
#  'already',
#  'also',
#  'always',
#  'amazing',
#  'america',
#  'amputate',
#  'analyze',
#  'anatomy',
#  'and',
#  'angel',
#  'angle',
#  'angry',
#  'animal',
#  'anniversary',
#  'announce',
#  'annoy',
#  'another',
#  'answer',
#  'any',
#  'anyway',
#  'apart',
#  'apartment',
#  'apostrophe',
#  'appear',
#  'appetite',
#  'apple',
#  'appointment',
#  'appreciate',
#  'approach',
#  'appropriate',
#  'approve',
#  'april',
#  'archery',
#  'area',
#  'argue',
#  'arizona',
#  'arm',
#  'army',
#  'around',
#  'arrest',
#  'arrive',
#  'arrogant',
#  'art',
#  'article',
#  'artist',
#  'asia',
#  'ask',
#  'asl',
#  'assist',
#  'assistant',
#  'assume',
#  'attend',
#  'attention',
#  'attitude',
#  'attorney',
#  'attract',
#  'auction',
#  'audience',
#  'audiologist',
#  'audiology',
#  'august',
#  'aunt',
#  'australia',
#  'austria',
#  'author',
#  'authority',
#  'autumn',
#  'available',
#  'average',
#  'avoid',
#  'awake',
#  'award',
#  'aware',
#  'away',
#  'awful',
#  'awkward',
#  'b',
#  'baby',
#  'babysitter',
#  'back',
#  'background',
#  'backpack',
#  'bacon',
#  'bad',
#  'bake',
#  'balance',
#  'bald',
#  'ball',
#  'balloon',
#  'banana',
#  'bank',
#  'baptize',
#  'bar',
#  'barely',
#  'bark',
#  'baseball',
#  'basement',
#  'basic',
#  'basketball',
#  'bath',
#  'bathroom',
#  'battery',
#  'battle',
#  'bear',
#  'beard',
#  'beautiful',
#  'because',
#  'become',
#  'bed',
#  'bedroom',
#  'bee',
#  'beer',
#  'before',
#  'beg',
#  'beginning',
#  'behavior',
#  'behind',
#  'belief',
#  'believe',
#  'bell',
#  'below',
#  'belt',
#  'benefit',
#  'berry',
#  'beside',
#  'best',
#  'bet',
#  'better',
#  'between',
#  'bible',
#  'bicycle',
#  'big',
#  'bike',
#  'binoculars',
#  'biology',
#  'bird',
#  'birth',
#  'birthday',
#  'bite',
#  'bitter',
#  'black',
#  'blame',
#  'blanket',
#  'blend',
#  'bless',
#  'blind',
#  'blood',
#  'blow',
#  'blue',
#  'boast',
#  'boat',
#  'body',
#  'boil',
#  'bone',
#  'book',
#  'bookshelf',
#  'bookstore',
#  'boots',
#  'bored',
#  'borrow',
#  'boss',
#  'both',
#  'bother',
#  'bottle',
#  'bottom',
#  'bowl',
#  'bowling',
#  'box',
#  'boxing',
#  'boy',
#  'boyfriend',
#  'bra',
#  'bracelet',
#  'brag',
#  'braid',
#  'brain',
#  'brave',
#  'bread',
#  'break',
#  'breakdown',
#  'breakfast',
#  'breathe',
#  'breeze',
#  'bribe',
#  'bridge',
#  'brief',
#  'bright',
#  'bring',
#  'brochure',
#  'broke',
#  'brother',
#  'brown',
#  'brush',
#  'buffalo',
#  'bug',
#  'build',
#  'building',
#  'bull',
#  'bully',
#  'burp',
#  'bus',
#  'bush',
#  'business',
#  'busy',
#  'but',
#  'butter',
#  'butterfly',
#  'button',
#  'buy',
#  'bye',
#  'cabbage',
#  'cabinet',
#  'cafeteria',
#  'cake',
#  'calculate',
#  'calculator',
#  'calculus',
#  'california',
#  'call',
#  'calm',
#  'camel',
#  'camera',
#  'camp',
#  'camping',
#  'can',
#  'canada',
#  'cancel',
#  'candidate',
#  'candle',
#  'candy',
#  'cannot',
#  'canoe',
#  'captain',
#  'caption',
#  'car',
#  'card',
#  'cards',
#  'care',
#  'careful',
#  'careless',
#  'carnival',
#  'carrot',
#  'carry',
#  'cat',
#  'catch',
#  'category',
#  'caterpillar',
#  'catholic',
#  'cause',
#  'ceiling',
#  'celebrate',
#  'cemetery',
#  'cent',
#  'center',
#  'cereal',
#  'certificate',
#  'chain',
#  'chair',
#  'challenge',
#  'champion',
#  'chance',
#  'change',
#  'chapter',
#  'character',
#  'chase',
#  'chat',
#  'cheap',
#  'cheat',
#  'check',
#  'cheerleader',
#  'cheese',
#  'chemical',
#  'chemistry',
#  'cherry',
#  'chicago',
#  'chicken',
#  'child',
#  'children',
#  'china',
#  'chocolate',
#  'choice',
#  'choir',
#  'choke',
#  'choose',
#  'chop',
#  'christ',
#  'christian',
#  'christmas',
#  'church',
#  'cigarette',
#  'circle',
#  'city',
#  'class',
#  'classroom',
#  'clean',
#  'clear',
#  'clever',
#  'click',
#  'climb',
#  'clock',
#  'close',
#  'closet',
#  'clothes',
#  'cloud',
#  'clown',
#  'clueless',
#  'clumsy',
#  'coach',
#  'coat',
#  'cochlear implant',
#  'coconut',
#  'coffee',
#  'cold',
#  'collect',
#  'college',
#  'color',
#  'comb',
#  'come',
#  'come here',
#  'comfortable',
#  'comma',
#  'command',
#  'comment',
#  'commit',
#  'committee',
#  'common',
#  'common sense',
#  'community',
#  'commute',
#  'company',
#  'compare',
#  'compete',
#  'complain',
#  'complete',
#  'complex',
#  'compromise',
#  'computer',
#  'concentrate',
#  'concept',
#  'concern',
#  'conflict',
#  'confront',
#  'confused',
#  'congratulations',
#  'congress',
#  'connect',
#  'conquer',
#  'consider',
#  'constitution',
#  'construct',
#  'consume',
#  'contact',
#  'contest',
#  'continue',
#  'contract',
#  'contribute',
#  'control',
#  'conversation',
#  'convert',
#  'convince',
#  'cook',
#  'cookie',
#  'cool',
#  'cooperate',
#  'cop',
#  'copy',
#  'corn',
#  'corner',
#  'correct',
#  'cost',
#  'couch',
#  'cough',
#  'counsel',
#  'counselor',
#  'count',
#  'country',
#  'court',
#  'cousin',
#  'cover',
#  'cow',
#  'crab',
#  'cracker',
#  'crash',
#  'crave',
#  'crazy',
#  'create',
#  'crocodile',
#  'cross',
#  'crown',
#  'cruel',
#  'crush',
#  'cry',
#  'cuba',
#  'culture',
#  'cup',
#  'curious',
#  'curriculum',
#  'curse',
#  'curtain',
#  'customer',
#  'cut',
#  'cute',
#  'd',
#  'dad',
#  'daily',
#  'damage',
#  'dance',
#  'dancer',
#  'danger',
#  'dangerous',
#  'dark',
#  'date',
#  'daughter',
#  'dawn',
#  'day',
#  'dead',
#  'deaf',
#  'death',
#  'debate',
#  'debt',
#  'december',
#  'decide',
#  'decorate',
#  'decrease',
#  'deduct',
#  'deep',
#  'deer',
#  'defeat',
#  'defend',
#  'degree',
#  'delay',
#  'delicious',
#  'deliver',
#  'demand',
#  'democrat',
#  'demonstrate',
#  'dentist',
#  'deny',
#  'deodorant',
#  'department',
#  'depend',
#  'deposit',
#  'depressed',
#  'descend']

# %%
#This is going to take in all file names, perct is our data split for train/val/test
#It will calculate the split then return the subset and the old files - the subset
def Split_Classes(files_for_class, perct, split_name):
    split_files = []
    remainder = {}
    for cls in files_for_class:

        if(split_name == "train"):
            count = int(math.floor(len(files_for_class[cls]) * perct))
        elif(split_name == "val"):
            count = int(math.ceil(len(files_for_class[cls]) * (perct * 2)))
        else:
            count = int(len(files_for_class[cls]))
        print(cls)
        print(count)
        split_files.extend(files_for_class[cls][:count])
        remainder[cls] = files_for_class[cls][count:]
        #print(split_files)
        #print(str(len(remainder)) + " REMAINDER FILE AMOUNT ")
    return split_files, remainder

#this is going to create each class and move the correct files into each train/val/test subset
#then it will put it into the class
def Create_Split_Folders(files_for_class,split_dir):
    #print(files_for_class)
    for fn in files_for_class:
        file_class = Get_Class(fn)
        os.makedirs(split_dir / file_class,exist_ok=True)
        file_id = fn.split("\\")[-1]
        dst = pathlib.Path(split_dir / file_class / file_id)
        #print("FN: " + str(fn) + "DST: " + str(dst))
        print(str(dst))
        shutil.copy(fn, dst)
        #print("test")
    #print("test")

# %%
#This is going to take our split {name : %} the base dir and all the original data
#splits = {"train": .5, "val": 0.25, "test": 0.25}
#base_dir = pathlib.Path('..\Data\Videos\wlasl-complete\sample_classes\ASL_subset')
def Sort_Videos(splits,subset_dir,files):
    files_for_class = Get_Class_Files(files)

    classes = list(files_for_class.keys())[:NUM_CLASSES]

    for cls in classes:
        random.shuffle(files_for_class[cls])

    # Only use the number of classes you want in the dictionary
    files_for_class = {x: files_for_class[x] for x in classes}
    dirs = {}
    for split_name, split_count in splits.items():
        print(split_name)
        os.makedirs(subset_dir / split_name,exist_ok=True)
        #print(split_name)
        split_dir = pathlib.Path(subset_dir / split_name)
        split_files, files_for_class = Split_Classes(files_for_class, split_count,split_name)
        #print(str(split_files))
        Create_Split_Folders(split_files,split_dir)
        dirs[split_name] = split_dir
    return dirs

# %%
base_dir = pathlib.Path('..\Data\wlasl-complete\ASL_full')
video_count_train = len(list(base_dir.glob('train/*/*.mp4')))
video_count_val = len(list(base_dir.glob('val/*/*.mp4')))
video_count_test = len(list(base_dir.glob('test/*/*.mp4')))
video_total = video_count_train + video_count_val + video_count_test
print(f"Total videos: {video_total}")
# Out:
# Total videos: 63180

# %%
#Make sure our format for the videos is the same. Will not need until new data 
def Format_Frame(frame, output_size):
    frame = tf.image.convert_image_dtype(frame, tf.float32)
    frame = tf.image.resize_with_pad(frame, *output_size)
    return frame

# %%
#returns an array of frames form a video_path, n_frames is how many videos we want
#and frame_step is how often we grab a fram
def Create_Frames(video_path, n_frames, output_size = (256,256), frame_step = 15):
    # Read each video frame by frame
    result = []
    src = cv2.VideoCapture(str(video_path))  
    #total video length
    video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)
    #how much of the video we need deending on how many frames we are taking
    need_length = 1 + (n_frames - 1) * frame_step
    #if we want more frames then the length just start at 0 seconds
    if need_length > video_length:
        start = 0
    #If we have enough video then we can start at 0 seconds or a little later to
    #avoid some empty starting frames
    #might want to adjust start so 0 seconds isnt the min
    else:
        max_start = video_length - need_length
        start = random.randint(0, max_start + 1)
    
    src.set(cv2.CAP_PROP_POS_FRAMES, start)
    # ret is a boolean indicating whether read was successful, frame is the image itself
    ret, frame = src.read()
    result.append(Format_Frame(frame, output_size))

    #go through every frame 
    for _ in range(n_frames - 1):
        for _ in range(frame_step):
            ret, frame = src.read()
        if ret:
            frame = Format_Frame(frame, output_size)
            result.append(frame)
        else:
            result.append(np.zeros_like(result[0]))
    src.release()
    result = np.array(result)[..., [2, 1, 0]]

    return result

# %%
video_path = "../Data/wlasl-complete/classes/book/07068.mp4"


sample_video = Create_Frames(video_path, n_frames = 10)
sample_video.shape
# Out:
# (10, 256, 256, 3)

# %%
def to_gif(images):
    converted_images = np.clip(images * 255, 0, 255).astype(np.uint8)
    imageio.mimsave('./animation.gif', converted_images, fps=10)
    return embed.embed_file('./animation.gif')

# %%
to_gif(sample_video)
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
class FrameGenerator:
    def __init__(self, path, n_frames, training = False):
        self.path = path
        self.n_frames = n_frames
        self.training = training
        self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
        self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

    def get_files_and_class_names(self):
        video_paths = list(self.path.glob('*/*.mp4'))
        classes = [p.parent.name for p in video_paths] 
        return video_paths, classes
    
    def __call__(self):
        video_paths, classes = self.get_files_and_class_names()

        pairs = list(zip(video_paths, classes))

        if self.training:
            random.shuffle(pairs)

        for path, name in pairs:
            video_frames = Create_Frames(path, self.n_frames) 
            label = self.class_ids_for_name[name] # Encode labels
            yield video_frames, label

# %%
splits = {"train": .70, "val": 0.25, "test": 0.05}
base_dir = pathlib.Path('..\Data\wlasl-complete\ASL_subset')
subset_paths = Sort_Videos(splits,base_dir,files)

fg = FrameGenerator(subset_paths['train'], 10, training=True)

frames, label = next(fg())

print(f"Shape: {frames.shape}")
print(f"Label: {label}")
# Out:
# train
# a
# 5
# a lot
# 5
# abdomen
# 5
# able
# 5
# about
# 10
# above
# 6
# accent
# 4
# accept
# 8
# accident
# 13
# accomplish
# 6
# accountant
# 5
# across
# 7
# act
# 4
# action
# 5
# active
# 5
# activity
# 5
# actor
# 7
# adapt
# 4
# add
# 7
# address
# 5
# adjective
# 4
# adjust
# 4
# admire
# 4
# admit
# 4
# adopt
# 6
# adult
# 8
# advanced
# 4
# advantage
# 6
# adverb
# 4
# affect
# 5
# afraid
# 5
# africa
# 12
# after
# 8
# afternoon
# 9
# again
# 11
# against
# 5
# age
# 9
# agenda
# 5
# ago
# 8
# agree
# 7
# agreement
# 4
# ahead
# 5
# aid
# 4
# aim
# 5
# airplane
# 7
# alarm
# 7
# alcohol
# 5
# algebra
# 5
# all
# 14
# all day
# 5
# allergy
# 7
# alligator
# 4
# allow
# 8
# almost
# 7
# alone
# 9
# alphabet
# 6
# already
# 7
# also
# 7
# always
# 9
# amazing
# 5
# america
# 8
# amputate
# 4
# analyze
# 7
# anatomy
# 4
# and
# 7
# angel
# 8
# angle
# 5
# angry
# 7
# animal
# 9
# anniversary
# 6
# announce
# 7
# annoy
# 4
# another
# 6
# answer
# 8
# any
# 8
# anyway
# 4
# apart
# 5
# apartment
# 7
# apostrophe
# 5
# appear
# 7
# appetite
# 5
# apple
# 13
# appointment
# 9
# appreciate
# 5
# approach
# 4
# appropriate
# 6
# approve
# 10
# april
# d
# 4
# dad
# 7
# daily
# 6
# damage
# 4
# dance
# 13
# dancer
# 4
# danger
# 4
# dangerous
# 4
# dark
# 13
# date
# 5
# daughter
# 11
# dawn
# 4
# day
# 10
# dead
# 8
# deaf
# 16
# death
# 4
# debate
# 4
# debt
# 4
# december
# 5
# decide
# 12
# decorate
# 9
# decrease
# 5
# deduct
# 5
# deep
# 9
# deer
# 9
# defeat
# 5
# defend
# 6
# degree
# 6
# delay
# 9
# delicious
# 9
# deliver
# 4
# demand
# 8
# democrat
# 4
# demonstrate
# 6
# dentist
# 9
# deny
# 7
# deodorant
# 7
# department
# 6
# depend
# 8
# deposit
# 5
# depressed
# 5
# descend
# 4
# ..\Data\wlasl-complete\ASL_subset\train\a\01611.mp4
# ..\Data\wlasl-complete\ASL_subset\train\a\01615.mp4
# ..\Data\wlasl-complete\ASL_subset\train\a\01613.mp4
# ..\Data\wlasl-complete\ASL_subset\train\a\00295.mp4
# ..\Data\wlasl-complete\ASL_subset\train\a\66039.mp4
# ..\Data\wlasl-complete\ASL_subset\train\a lot\02124.mp4
# ..\Data\wlasl-complete\ASL_subset\train\a lot\02128.mp4
# ..\Data\wlasl-complete\ASL_subset\train\a lot\02125.mp4
# ..\Data\wlasl-complete\ASL_subset\train\a lot\02126.mp4
# ..\Data\wlasl-complete\ASL_subset\train\a lot\02130.mp4
# ..\Data\wlasl-complete\ASL_subset\train\abdomen\00337.mp4
# ..\Data\wlasl-complete\ASL_subset\train\abdomen\00338.mp4
# ..\Data\wlasl-complete\ASL_subset\train\abdomen\00339.mp4
# ..\Data\wlasl-complete\ASL_subset\train\abdomen\00333.mp4
# ..\Data\wlasl-complete\ASL_subset\train\abdomen\00335.mp4
# ..\Data\wlasl-complete\ASL_subset\train\able\00383.mp4
# ..\Data\wlasl-complete\ASL_subset\train\able\00377.mp4
# ..\Data\wlasl-complete\ASL_subset\train\able\00374.mp4
# ..\Data\wlasl-complete\ASL_subset\train\able\00381.mp4
# ..\Data\wlasl-complete\ASL_subset\train\able\00382.mp4
# ..\Data\wlasl-complete\ASL_subset\train\about\00419.mp4
# ..\Data\wlasl-complete\ASL_subset\train\about\00412.mp4
# ..\Data\wlasl-complete\ASL_subset\train\about\00414.mp4
# ..\Data\wlasl-complete\ASL_subset\train\about\00425.mp4
# ..\Data\wlasl-complete\ASL_subset\train\about\65002.mp4
# ..\Data\wlasl-complete\ASL_subset\train\about\67339.mp4
# ..\Data\wlasl-complete\ASL_subset\train\about\67341.mp4
# ..\Data\wlasl-complete\ASL_subset\train\about\00416.mp4
# ..\Data\wlasl-complete\ASL_subset\train\about\00421.mp4
# ..\Data\wlasl-complete\ASL_subset\train\about\65003.mp4
# ..\Data\wlasl-complete\ASL_subset\train\above\00432.mp4
# ..\Data\wlasl-complete\ASL_subset\train\above\00433.mp4
# ..\Data\wlasl-complete\ASL_subset\train\above\70167.mp4
# ..\Data\wlasl-complete\ASL_subset\train\above\65004.mp4
# ..\Data\wlasl-complete\ASL_subset\train\above\00430.mp4
# ..\Data\wlasl-complete\ASL_subset\train\above\00435.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accent\00586.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accent\00587.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accent\00581.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accent\00584.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accept\00603.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accept\00594.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accept\65007.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accept\00602.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accept\00598.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accept\00597.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accept\00601.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accept\00599.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00631.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00630.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00635.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00628.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00629.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\65009.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00624.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00627.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00618.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00626.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00625.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00636.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accident\00638.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accomplish\00667.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accomplish\00662.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accomplish\00668.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accomplish\65010.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accomplish\00663.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accomplish\00664.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accountant\00693.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accountant\65011.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accountant\00690.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accountant\00692.mp4
# ..\Data\wlasl-complete\ASL_subset\train\accountant\00691.mp4
# ..\Data\wlasl-complete\ASL_subset\train\across\00841.mp4
# ..\Data\wlasl-complete\ASL_subset\train\across\00832.mp4
# ..\Data\wlasl-complete\ASL_subset\train\across\00838.mp4
# ..\Data\wlasl-complete\ASL_subset\train\across\00840.mp4
# ..\Data\wlasl-complete\ASL_subset\train\across\00829.mp4
# ..\Data\wlasl-complete\ASL_subset\train\across\00839.mp4
# ..\Data\wlasl-complete\ASL_subset\train\across\00836.mp4
# ..\Data\wlasl-complete\ASL_subset\train\act\00846.mp4
# ..\Data\wlasl-complete\ASL_subset\train\act\00849.mp4
# ..\Data\wlasl-complete\ASL_subset\train\act\00851.mp4
# ..\Data\wlasl-complete\ASL_subset\train\act\00850.mp4
# ..\Data\wlasl-complete\ASL_subset\train\action\00856.mp4
# ..\Data\wlasl-complete\ASL_subset\train\action\00857.mp4
# ..\Data\wlasl-complete\ASL_subset\train\action\67345.mp4
# ..\Data\wlasl-complete\ASL_subset\train\action\65015.mp4
# ..\Data\wlasl-complete\ASL_subset\train\action\00855.mp4
# ..\Data\wlasl-complete\ASL_subset\train\active\00872.mp4
# ..\Data\wlasl-complete\ASL_subset\train\active\00868.mp4
# ..\Data\wlasl-complete\ASL_subset\train\active\00873.mp4
# ..\Data\wlasl-complete\ASL_subset\train\active\00871.mp4
# ..\Data\wlasl-complete\ASL_subset\train\active\00874.mp4
# ..\Data\wlasl-complete\ASL_subset\train\activity\00886.mp4
# ..\Data\wlasl-complete\ASL_subset\train\activity\00893.mp4
# ..\Data\wlasl-complete\ASL_subset\train\activity\00892.mp4
# ..\Data\wlasl-complete\ASL_subset\train\activity\65016.mp4
# ..\Data\wlasl-complete\ASL_subset\train\activity\00890.mp4
# ..\Data\wlasl-complete\ASL_subset\train\actor\00897.mp4
# ..\Data\wlasl-complete\ASL_subset\train\actor\00901.mp4
# ..\Data\wlasl-complete\ASL_subset\train\actor\00899.mp4
# ..\Data\wlasl-complete\ASL_subset\train\actor\65017.mp4
# ..\Data\wlasl-complete\ASL_subset\train\actor\00903.mp4
# ..\Data\wlasl-complete\ASL_subset\train\actor\00900.mp4
# ..\Data\wlasl-complete\ASL_subset\train\actor\00904.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adapt\00950.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adapt\00951.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adapt\00944.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adapt\00946.mp4
# ..\Data\wlasl-complete\ASL_subset\train\add\00966.mp4
# ..\Data\wlasl-complete\ASL_subset\train\add\00962.mp4
# ..\Data\wlasl-complete\ASL_subset\train\add\00973.mp4
# ..\Data\wlasl-complete\ASL_subset\train\add\65018.mp4
# ..\Data\wlasl-complete\ASL_subset\train\add\00964.mp4
# ..\Data\wlasl-complete\ASL_subset\train\add\00967.mp4
# ..\Data\wlasl-complete\ASL_subset\train\add\00972.mp4
# ..\Data\wlasl-complete\ASL_subset\train\address\01020.mp4
# ..\Data\wlasl-complete\ASL_subset\train\address\01012.mp4
# ..\Data\wlasl-complete\ASL_subset\train\address\01016.mp4
# ..\Data\wlasl-complete\ASL_subset\train\address\01018.mp4
# ..\Data\wlasl-complete\ASL_subset\train\address\01011.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adjective\01065.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adjective\01068.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adjective\01064.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adjective\01062.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adjust\01078.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adjust\01079.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adjust\01077.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adjust\01076.mp4
# ..\Data\wlasl-complete\ASL_subset\train\admire\01102.mp4
# ..\Data\wlasl-complete\ASL_subset\train\admire\01100.mp4
# ..\Data\wlasl-complete\ASL_subset\train\admire\01107.mp4
# ..\Data\wlasl-complete\ASL_subset\train\admire\65020.mp4
# ..\Data\wlasl-complete\ASL_subset\train\admit\01127.mp4
# ..\Data\wlasl-complete\ASL_subset\train\admit\01118.mp4
# ..\Data\wlasl-complete\ASL_subset\train\admit\01120.mp4
# ..\Data\wlasl-complete\ASL_subset\train\admit\01121.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adopt\01149.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adopt\65022.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adopt\01157.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adopt\01159.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adopt\01160.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adopt\68958.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adult\01214.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adult\01211.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adult\01209.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adult\01206.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adult\01212.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adult\01216.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adult\01194.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adult\65024.mp4
# ..\Data\wlasl-complete\ASL_subset\train\advanced\01224.mp4
# ..\Data\wlasl-complete\ASL_subset\train\advanced\01229.mp4
# ..\Data\wlasl-complete\ASL_subset\train\advanced\01228.mp4
# ..\Data\wlasl-complete\ASL_subset\train\advanced\01231.mp4
# ..\Data\wlasl-complete\ASL_subset\train\advantage\01247.mp4
# ..\Data\wlasl-complete\ASL_subset\train\advantage\01249.mp4
# ..\Data\wlasl-complete\ASL_subset\train\advantage\01242.mp4
# ..\Data\wlasl-complete\ASL_subset\train\advantage\65025.mp4
# ..\Data\wlasl-complete\ASL_subset\train\advantage\01244.mp4
# ..\Data\wlasl-complete\ASL_subset\train\advantage\01252.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adverb\01268.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adverb\01266.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adverb\01263.mp4
# ..\Data\wlasl-complete\ASL_subset\train\adverb\01264.mp4
# ..\Data\wlasl-complete\ASL_subset\train\affect\01325.mp4
# ..\Data\wlasl-complete\ASL_subset\train\affect\01327.mp4
# ..\Data\wlasl-complete\ASL_subset\train\affect\01319.mp4
# ..\Data\wlasl-complete\ASL_subset\train\affect\01318.mp4
# ..\Data\wlasl-complete\ASL_subset\train\affect\01320.mp4
# ..\Data\wlasl-complete\ASL_subset\train\afraid\01373.mp4
# ..\Data\wlasl-complete\ASL_subset\train\afraid\01377.mp4
# ..\Data\wlasl-complete\ASL_subset\train\afraid\01374.mp4
# ..\Data\wlasl-complete\ASL_subset\train\afraid\01381.mp4
# ..\Data\wlasl-complete\ASL_subset\train\afraid\01379.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\65029.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\01394.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\01388.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\01387.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\01396.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\01391.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\01398.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\01384.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\01383.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\67350.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\01397.mp4
# ..\Data\wlasl-complete\ASL_subset\train\africa\01386.mp4
# ..\Data\wlasl-complete\ASL_subset\train\after\01419.mp4
# ..\Data\wlasl-complete\ASL_subset\train\after\01411.mp4
# ..\Data\wlasl-complete\ASL_subset\train\after\01421.mp4
# ..\Data\wlasl-complete\ASL_subset\train\after\01428.mp4
# ..\Data\wlasl-complete\ASL_subset\train\after\01427.mp4
# ..\Data\wlasl-complete\ASL_subset\train\after\01422.mp4
# ..\Data\wlasl-complete\ASL_subset\train\after
mp4
# ..\Data\wlasl-complete\ASL_subset\test\cheat\67489.mp4
# ..\Data\wlasl-complete\ASL_subset\test\check\10199.mp4
# ..\Data\wlasl-complete\ASL_subset\test\check\10188.mp4
# ..\Data\wlasl-complete\ASL_subset\test\check\67491.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cheerleader\10249.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cheese\10272.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cheese\10268.mp4
# ..\Data\wlasl-complete\ASL_subset\test\chemical\10299.mp4
# ..\Data\wlasl-complete\ASL_subset\test\chemistry\10308.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cherry\10340.mp4
# ..\Data\wlasl-complete\ASL_subset\test\chicago\67494.mp4
# ..\Data\wlasl-complete\ASL_subset\test\chicken\10411.mp4
# ..\Data\wlasl-complete\ASL_subset\test\chicken\70060.mp4
# ..\Data\wlasl-complete\ASL_subset\test\child\10446.mp4
# ..\Data\wlasl-complete\ASL_subset\test\child\10447.mp4
# ..\Data\wlasl-complete\ASL_subset\test\children\10466.mp4
# ..\Data\wlasl-complete\ASL_subset\test\children\10473.mp4
# ..\Data\wlasl-complete\ASL_subset\test\china\10519.mp4
# ..\Data\wlasl-complete\ASL_subset\test\chocolate\10584.mp4
# ..\Data\wlasl-complete\ASL_subset\test\chocolate\10585.mp4
# ..\Data\wlasl-complete\ASL_subset\test\choice\10589.mp4
# ..\Data\wlasl-complete\ASL_subset\test\choice\10591.mp4
# ..\Data\wlasl-complete\ASL_subset\test\choir\10601.mp4
# ..\Data\wlasl-complete\ASL_subset\test\choke\10611.mp4
# ..\Data\wlasl-complete\ASL_subset\test\choose\10628.mp4
# ..\Data\wlasl-complete\ASL_subset\test\choose\10636.mp4
# ..\Data\wlasl-complete\ASL_subset\test\chop\10652.mp4
# ..\Data\wlasl-complete\ASL_subset\test\christ\10683.mp4
# ..\Data\wlasl-complete\ASL_subset\test\christian\10685.mp4
# ..\Data\wlasl-complete\ASL_subset\test\christmas\10708.mp4
# ..\Data\wlasl-complete\ASL_subset\test\christmas\10703.mp4
# ..\Data\wlasl-complete\ASL_subset\test\church\10774.mp4
# ..\Data\wlasl-complete\ASL_subset\test\church\10772.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cigarette\10792.mp4
# ..\Data\wlasl-complete\ASL_subset\test\circle\10817.mp4
# ..\Data\wlasl-complete\ASL_subset\test\city\65363.mp4
# ..\Data\wlasl-complete\ASL_subset\test\city\68374.mp4
# ..\Data\wlasl-complete\ASL_subset\test\city\10892.mp4
# ..\Data\wlasl-complete\ASL_subset\test\class\10975.mp4
# ..\Data\wlasl-complete\ASL_subset\test\class\10965.mp4
# ..\Data\wlasl-complete\ASL_subset\test\class\10970.mp4
# ..\Data\wlasl-complete\ASL_subset\test\classroom\11014.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clean\11030.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clean\11034.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clear\11067.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clever\11088.mp4
# ..\Data\wlasl-complete\ASL_subset\test\click\11106.mp4
# ..\Data\wlasl-complete\ASL_subset\test\climb\11155.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clock\11214.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clock\11201.mp4
# ..\Data\wlasl-complete\ASL_subset\test\close\11265.mp4
# ..\Data\wlasl-complete\ASL_subset\test\close\11260.mp4
# ..\Data\wlasl-complete\ASL_subset\test\closet\11284.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clothes\11322.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clothes\11310.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clothes\11312.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clothes\11305.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cloud\11361.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cloud\67506.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clown\65372.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clueless\11408.mp4
# ..\Data\wlasl-complete\ASL_subset\test\clumsy\11423.mp4
# ..\Data\wlasl-complete\ASL_subset\test\coach\11437.mp4
# ..\Data\wlasl-complete\ASL_subset\test\coat\11471.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cochlear implant\11501.mp4
# ..\Data\wlasl-complete\ASL_subset\test\coconut\11528.mp4
# ..\Data\wlasl-complete\ASL_subset\test\coffee\11560.mp4
# ..\Data\wlasl-complete\ASL_subset\test\coffee\65375.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cold\11623.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cold\11621.mp4
# ..\Data\wlasl-complete\ASL_subset\test\collect\11686.mp4
# ..\Data\wlasl-complete\ASL_subset\test\college\11713.mp4
# ..\Data\wlasl-complete\ASL_subset\test\college\11708.mp4
# ..\Data\wlasl-complete\ASL_subset\test\color\67514.mp4
# ..\Data\wlasl-complete\ASL_subset\test\color\11775.mp4
# ..\Data\wlasl-complete\ASL_subset\test\color\11772.mp4
# ..\Data\wlasl-complete\ASL_subset\test\comb\11812.mp4
# ..\Data\wlasl-complete\ASL_subset\test\comb\11820.mp4
# ..\Data\wlasl-complete\ASL_subset\test\come\11878.mp4
# ..\Data\wlasl-complete\ASL_subset\test\come here\11867.mp4
# ..\Data\wlasl-complete\ASL_subset\test\comfortable\11908.mp4
# ..\Data\wlasl-complete\ASL_subset\test\comfortable\11900.mp4
# ..\Data\wlasl-complete\ASL_subset\test\comma\11935.mp4
# ..\Data\wlasl-complete\ASL_subset\test\command\11951.mp4
# ..\Data\wlasl-complete\ASL_subset\test\comment\11977.mp4
# ..\Data\wlasl-complete\ASL_subset\test\commit\11996.mp4
# ..\Data\wlasl-complete\ASL_subset\test\committee\12006.mp4
# ..\Data\wlasl-complete\ASL_subset\test\common\69276.mp4
# ..\Data\wlasl-complete\ASL_subset\test\common sense\12028.mp4
# ..\Data\wlasl-complete\ASL_subset\test\community\12058.mp4
# ..\Data\wlasl-complete\ASL_subset\test\commute\12077.mp4
# ..\Data\wlasl-complete\ASL_subset\test\company\12102.mp4
# ..\Data\wlasl-complete\ASL_subset\test\compare\65386.mp4
# ..\Data\wlasl-complete\ASL_subset\test\compare\12114.mp4
# ..\Data\wlasl-complete\ASL_subset\test\compete\12158.mp4
# ..\Data\wlasl-complete\ASL_subset\test\complain\12198.mp4
# ..\Data\wlasl-complete\ASL_subset\test\complete\12221.mp4
# ..\Data\wlasl-complete\ASL_subset\test\complex\12223.mp4
# ..\Data\wlasl-complete\ASL_subset\test\complex\12225.mp4
# ..\Data\wlasl-complete\ASL_subset\test\compromise\12300.mp4
# ..\Data\wlasl-complete\ASL_subset\test\computer\12322.mp4
# ..\Data\wlasl-complete\ASL_subset\test\computer\12326.mp4
# ..\Data\wlasl-complete\ASL_subset\test\computer\69054.mp4
# ..\Data\wlasl-complete\ASL_subset\test\computer\12317.mp4
# ..\Data\wlasl-complete\ASL_subset\test\concentrate\12396.mp4
# ..\Data\wlasl-complete\ASL_subset\test\concept\12405.mp4
# ..\Data\wlasl-complete\ASL_subset\test\concern\12416.mp4
# ..\Data\wlasl-complete\ASL_subset\test\conflict\12589.mp4
# ..\Data\wlasl-complete\ASL_subset\test\conflict\65394.mp4
# ..\Data\wlasl-complete\ASL_subset\test\confront\12609.mp4
# ..\Data\wlasl-complete\ASL_subset\test\confused\12613.mp4
# ..\Data\wlasl-complete\ASL_subset\test\congratulations\12641.mp4
# ..\Data\wlasl-complete\ASL_subset\test\congress\12648.mp4
# ..\Data\wlasl-complete\ASL_subset\test\connect\12675.mp4
# ..\Data\wlasl-complete\ASL_subset\test\conquer\12697.mp4
# ..\Data\wlasl-complete\ASL_subset\test\consider\12758.mp4
# ..\Data\wlasl-complete\ASL_subset\test\constitution\12814.mp4
# ..\Data\wlasl-complete\ASL_subset\test\construct\12823.mp4
# ..\Data\wlasl-complete\ASL_subset\test\consume\12861.mp4
# ..\Data\wlasl-complete\ASL_subset\test\contact\12875.mp4
# ..\Data\wlasl-complete\ASL_subset\test\contact\12877.mp4
# ..\Data\wlasl-complete\ASL_subset\test\contest\12943.mp4
# ..\Data\wlasl-complete\ASL_subset\test\continue\67525.mp4
# ..\Data\wlasl-complete\ASL_subset\test\continue\12967.mp4
# ..\Data\wlasl-complete\ASL_subset\test\contract\12988.mp4
# ..\Data\wlasl-complete\ASL_subset\test\contribute\13019.mp4
# ..\Data\wlasl-complete\ASL_subset\test\control\13042.mp4
# ..\Data\wlasl-complete\ASL_subset\test\conversation\13094.mp4
# ..\Data\wlasl-complete\ASL_subset\test\convert\13114.mp4
# ..\Data\wlasl-complete\ASL_subset\test\convince\13146.mp4
# ..\Data\wlasl-complete\ASL_subset\test\convince\13139.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cook\13154.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cook\13166.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cook\70030.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cookie\13179.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cookie\69280.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cool\13207.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cool\69281.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cool\13199.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cooperate\13223.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cop\13246.mp4
# ..\Data\wlasl-complete\ASL_subset\test\copy\13273.mp4
# ..\Data\wlasl-complete\ASL_subset\test\copy\13272.mp4
# ..\Data\wlasl-complete\ASL_subset\test\corn\65409.mp4
# ..\Data\wlasl-complete\ASL_subset\test\corn\13334.mp4
# ..\Data\wlasl-complete\ASL_subset\test\corn\69282.mp4
# ..\Data\wlasl-complete\ASL_subset\test\corner\70181.mp4
# ..\Data\wlasl-complete\ASL_subset\test\corner\13320.mp4
# ..\Data\wlasl-complete\ASL_subset\test\correct\13359.mp4
# ..\Data\wlasl-complete\ASL_subset\test\correct\13355.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cost\13424.mp4
# ..\Data\wlasl-complete\ASL_subset\test\couch\13463.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cough\13475.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cough\13470.mp4
# ..\Data\wlasl-complete\ASL_subset\test\counsel\13498.mp4
# ..\Data\wlasl-complete\ASL_subset\test\counselor\13509.mp4
# ..\Data\wlasl-complete\ASL_subset\test\count\65413.mp4
# ..\Data\wlasl-complete\ASL_subset\test\country\13545.mp4
# ..\Data\wlasl-complete\ASL_subset\test\country\13552.mp4
# ..\Data\wlasl-complete\ASL_subset\test\court\13618.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cousin\13638.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cousin\13631.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cousin\68592.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cover\13663.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cover\13657.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cow\13695.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cow\13701.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cow\13707.mp4
# ..\Data\wlasl-complete\ASL_subset\test\crab\13734.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cracker\13747.mp4
# ..\Data\wlasl-complete\ASL_subset\test\crash\13802.mp4
# ..\Data\wlasl-complete\ASL_subset\test\crash\13810.mp4
# ..\Data\wlasl-complete\ASL_subset\test\crave\13821.mp4
# ..\Data\wlasl-complete\ASL_subset\test\crazy\13856.mp4
# ..\Data\wlasl-complete\ASL_subset\test\crazy\65421.mp4
# ..\Data\wlasl-complete\ASL_subset\test\create\13880.mp4
# ..\Data\wlasl-complete\ASL_subset\test\crocodile\14013.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cross\14050.mp4
# ..\Data\wlasl-complete\ASL_subset\test\crown\14106.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cruel\14131.mp4
# ..\Data\wlasl-complete\ASL_subset\test\crush\69286.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cry\14174.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cry\14186.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cry\14187.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cuba\14209.mp4
# ..\Data\wlasl-complete\ASL_subset\test\culture\14267.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cup\14296.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cup\14298.mp4
# ..\Data\wlasl-complete\ASL_subset\test\curious\14318.mp4
# ..\Data\wlasl-complete\ASL_subset\test\curriculum\14370.mp4
# ..\Data\wlasl-complete\ASL_subset\test\curse\14379.mp4
# ..\Data\wlasl-complete\ASL_subset\test\curse\14384.mp4
# ..\Data\wlasl-complete\ASL_subset\test\curtain\14394.mp4
# ..\Data\wlasl-complete\ASL_subset\test\customer\14436.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cut\14473.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cut\14482.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cute\67548.mp4
# ..\Data\wlasl-complete\ASL_subset\test\cute\14451.mp4
# ..\Data\wlasl-complete\ASL_subset\test\d\15999.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dad\14565.mp4
# ..\Data\wlasl-complete\ASL_subset\test\daily\14580.mp4
# ..\Data\wlasl-complete\ASL_subset\test\damage\14601.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dance\70152.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dance\14622.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dance\14629.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dancer\14634.mp4
# ..\Data\wlasl-complete\ASL_subset\test\danger\14649.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dangerous\65437.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dark\14685.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dark\14669.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dark\14679.mp4
# ..\Data\wlasl-complete\ASL_subset\test\date\14732.mp4
# ..\Data\wlasl-complete\ASL_subset\test\daughter\14758.mp4
# ..\Data\wlasl-complete\ASL_subset\test\daughter\68858.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dawn\14776.mp4
# ..\Data\wlasl-complete\ASL_subset\test\day\14780.mp4
# ..\Data\wlasl-complete\ASL_subset\test\day\14796.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dead\14836.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dead\14845.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deaf\14886.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deaf\14883.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deaf\14896.mp4
# ..\Data\wlasl-complete\ASL_subset\test\death\14957.mp4
# ..\Data\wlasl-complete\ASL_subset\test\debate\14964.mp4
# ..\Data\wlasl-complete\ASL_subset\test\debt\14982.mp4
# ..\Data\wlasl-complete\ASL_subset\test\december\15017.mp4
# ..\Data\wlasl-complete\ASL_subset\test\decide\15042.mp4
# ..\Data\wlasl-complete\ASL_subset\test\decide\15036.mp4
# ..\Data\wlasl-complete\ASL_subset\test\decide\67556.mp4
# ..\Data\wlasl-complete\ASL_subset\test\decorate\15101.mp4
# ..\Data\wlasl-complete\ASL_subset\test\decorate\15094.mp4
# ..\Data\wlasl-complete\ASL_subset\test\decrease\15120.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deduct\15144.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deep\15165.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deep\15164.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deer\15171.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deer\15172.mp4
# ..\Data\wlasl-complete\ASL_subset\test\defeat\15185.mp4
# ..\Data\wlasl-complete\ASL_subset\test\defend\15216.mp4
# ..\Data\wlasl-complete\ASL_subset\test\degree\15294.mp4
# ..\Data\wlasl-complete\ASL_subset\test\delay\15331.mp4
# ..\Data\wlasl-complete\ASL_subset\test\delay\15328.mp4
# ..\Data\wlasl-complete\ASL_subset\test\delicious\65457.mp4
# ..\Data\wlasl-complete\ASL_subset\test\delicious\67559.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deliver\15405.mp4
# ..\Data\wlasl-complete\ASL_subset\test\demand\15428.mp4
# ..\Data\wlasl-complete\ASL_subset\test\demand\15422.mp4
# ..\Data\wlasl-complete\ASL_subset\test\democrat\15447.mp4
# ..\Data\wlasl-complete\ASL_subset\test\demonstrate\15474.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dentist\67561.mp4
# ..\Data\wlasl-complete\ASL_subset\test\dentist\15533.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deny\15550.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deodorant\15556.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deodorant\65462.mp4
# ..\Data\wlasl-complete\ASL_subset\test\department\15578.mp4
# ..\Data\wlasl-complete\ASL_subset\test\depend\15606.mp4
# ..\Data\wlasl-complete\ASL_subset\test\depend\15594.mp4
# ..\Data\wlasl-complete\ASL_subset\test\deposit\15635.mp4
# ..\Data\wlasl-complete\ASL_subset\test\depressed\15649.mp4
# ..\Data\wlasl-complete\ASL_subset\test\descend\15691.mp4
# Shape: (10, 256, 256, 3)
# Label: 35

# %%
# Create the training set
output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))
train_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['train'], 10, training=True),
                                          output_signature = output_signature)

# %%
for frames, labels in train_ds.take(10):
    print(labels)
# Out:
# tf.Tensor(248, shape=(), dtype=int16)
# tf.Tensor(433, shape=(), dtype=int16)
# tf.Tensor(57, shape=(), dtype=int16)
# tf.Tensor(137, shape=(), dtype=int16)
# tf.Tensor(226, shape=(), dtype=int16)
# tf.Tensor(65, shape=(), dtype=int16)
# tf.Tensor(356, shape=(), dtype=int16)
# tf.Tensor(338, shape=(), dtype=int16)
# tf.Tensor(471, shape=(), dtype=int16)
# tf.Tensor(28, shape=(), dtype=int16)

# %%
# Create the validation set
val_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['val'], 10),
                                        output_signature = output_signature)

# %%
# Create the test set
test_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['test'], 10),
                                        output_signature = output_signature)

# %%
# Print the shapes of the data
train_frames, train_labels = next(iter(train_ds))
print(f'Shape of training set of frames: {train_frames.shape}')
print(f'Shape of training labels: {train_labels.shape}')

val_frames, val_labels = next(iter(val_ds))
print(f'Shape of validation set of frames: {val_frames.shape}')
print(f'Shape of validation labels: {val_labels.shape}')

test_frames, test_labels = next(iter(test_ds))
print(f'Shape of test set of frames: {test_frames.shape}')
print(f'Shape of test labels: {test_labels.shape}')
# Out:
# Shape of training set of frames: (10, 256, 256, 3)
# Shape of training labels: ()
# Shape of validation set of frames: (10, 256, 256, 3)
# Shape of validation labels: ()
# Shape of test set of frames: (10, 256, 256, 3)
# Shape of test labels: ()

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
train_ds = train_ds.batch(32)
val_ds = val_ds.batch(32)
test_ds = test_ds.batch(32)
train_frames, train_labels = next(iter(train_ds))
print(f'Shape of training set of frames: {train_frames.shape}')
print(f'Shape of training labels: {train_labels.shape}')

val_frames, val_labels = next(iter(val_ds))
print(f'Shape of validation set of frames: {val_frames.shape}')
print(f'Shape of validation labels: {val_labels.shape}')

test_frames, test_labels = next(iter(test_ds))
print(f'Shape of test set of frames: {test_frames.shape}')
print(f'Shape of test labels: {test_labels.shape}')
# Out:
# Shape of training set of frames: (32, 10, 256, 256, 3)
# Shape of training labels: (32,)
# Shape of validation set of frames: (32, 10, 256, 256, 3)
# Shape of validation labels: (32,)
# Shape of test set of frames: (32, 10, 256, 256, 3)
# Shape of test labels: (32,)

# %%
net = tf.keras.applications.efficientnet_v2.EfficientNetV2B0(include_top = False)
net.trainable = False

model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(scale=255),
    tf.keras.layers.TimeDistributed(net),
    tf.keras.layers.Dense(len(classes)),
    tf.keras.layers.GlobalAveragePooling3D()
])

model.compile(optimizer = 'adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['acc','sparse_categorical_accuracy'])


#model.summary()

# %%
history = model.fit(train_ds, 
          epochs = 150,
          validation_data = val_ds)
# Out:
# Epoch 1/150
#     659/Unknown - 1697s 2s/step - loss: 7.9793 - acc: 0.0020 - sparse_categorical_accuracy: 0.0020
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 history = model.fit(train_ds,
#       2           epochs = 150,
#       3           validation_data = val_ds)
#
# File ~\.conda\envs\ASL\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\.conda\envs\ASL\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'IteratorGetNext' defined at (most recent call last):
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#       app.start()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#       result = self._run_cell(
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#       result = runner(coro)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\christian.y\AppData\Local\Temp\ipykernel_25096\4060572860.py", line 1, in <module>
#       history = model.fit(train_ds,
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\engine\training.py", line 1606, in fit
#       val_logs = self.evaluate(
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\engine\training.py", line 1947, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\engine\training.py", line 1727, in test_function
#       return step_function(self, iterator)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\engine\training.py", line 1712, in step_function
#       data = next(iterator)
# Node: 'IteratorGetNext'
# Detected at node 'IteratorGetNext' defined at (most recent call last):
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#       app.start()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#       result = self._run_cell(
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#       result = runner(coro)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\christian.y\AppData\Local\Temp\ipykernel_25096\4060572860.py", line 1, in <module>
#       history = model.fit(train_ds,
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\engine\training.py", line 1606, in fit
#       val_logs = self.evaluate(
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\engine\training.py", line 1947, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\engine\training.py", line 1727, in test_function
#       return step_function(self, iterator)
#     File "C:\Users\christian.y\.conda\envs\ASL\lib\site-packages\keras\engine\training.py", line 1712, in step_function
#       data = next(iterator)
# Node: 'IteratorGetNext'
# 2 root error(s) found.
#   (0) RESOURCE_EXHAUSTED:  Failed to allocate memory for the batch of component 0
# 	 [[{{node IteratorGetNext}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[IteratorGetNext/_4]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) RESOURCE_EXHAUSTED:  Failed to allocate memory for the batch of component 0
# 	 [[{{node IteratorGetNext}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_test_function_6977929]

# %%
#model.save_weights('ASL_3D_full_200.h5')

# %%
net = tf.keras.applications.efficientnet_v2.EfficientNetV2B0(include_top = False)
net.trainable = False

model2 = tf.keras.Sequential([
    tf.keras.layers.Rescaling(scale=255),
    tf.keras.layers.TimeDistributed(net),
    tf.keras.layers.Dense(len(classes)),
    tf.keras.layers.GlobalAveragePooling3D()
])

model2.compile(optimizer = 'adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['acc','sparse_categorical_accuracy'])

model2.built = True
#model.summary()

# %%
history = model2.fit(train_ds, 
          epochs = 1,
          validation_data = val_ds)
# Out:
# 109/109 [==============================] - 291s 2s/step - loss: 6.4866 - acc: 0.0060 - sparse_categorical_accuracy: 0.0060 - val_loss: 6.2677 - val_acc: 0.0036 - val_sparse_categorical_accuracy: 0.0036

# %%
model2.load_weights('ASL_3D_sample_700.h5')

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(700)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy',color="orange")
plt.plot(epochs_range, val_acc, label='Validation Accuracy',color="blue")
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss',color="orange")
plt.plot(epochs_range, val_loss, label='Validation Loss',color="blue")
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
score = model2.evaluate(test_ds)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
predict=model2.predict(test_ds)
y_classes = predict.argmax(axis=-1)
pred = np.argmax(y_classes)
print(y_classes)
# Out:
# 24/24 [==============================] - 41s 2s/step - loss: 2.6695 - acc: 0.8156 - sparse_categorical_accuracy: 0.8156
# Test loss: 2.6694765090942383
# Test accuracy: 0.8156498670578003
# 24/24 [==============================] - 44s 2s/step
# [  0   1   2 280   4   4   5   6   7   7   8   8   8   9  10  11  12  16
#  182  15  16  17  18  18 251  20  21  22  23   7  25  25  26  27  28  29
#   30  31  31  31  32 145  33  33  34  34  35  36  36  37 168  38  39  40
