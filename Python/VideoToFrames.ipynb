# %% [markdown]
# #### Imports

# %%
import tensorflow as tf
import cv2
import os

# %% [markdown]
# #### Loading DIR

# %%
base_dir = 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\'

# Parameters for video frames
width, height = 224, 224

# List of subfolders (each representing a class)
class_folders = [
    os.path.join(base_dir, class_folder)
    for class_folder in os.scandir(base_dir)
    if class_folder.is_dir()
]
print(len(class_folders))
# Out:
# 2000

# %% [markdown]
# #### Generate File Names

# %%
video_files = []
for class_folder in class_folders:
    video_files.extend([os.path.join(class_folder, file) for file in os.listdir(class_folder)])
print(video_files)
# Out:
# ['D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a\\01610.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a\\01611.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a\\01612.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a\\01615.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a\\66039.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a lot\\02124.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a lot\\02125.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a lot\\02126.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a lot\\02128.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a lot\\02129.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a lot\\02130.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\a lot\\02131.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\abdomen\\00335.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\SL\\abdomen\\00336.mp4', 'D:\\CSP400\\CSP400_ASLToText\\Data\\dataset\\S
# ...

# %% [markdown]
# #### Create dataset of slices

# %%
dataset = tf.data.Dataset.from_tensor_slices(video_files)
print(dataset)
# Out:
# <TensorSliceDataset element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %% [markdown]
# #### Convert into map for the dataset.

# %%
dataset = dataset.map(load_video_frames)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\CSP400\CSP400_ASLToText\Python\VideoToFrames.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/CSP400/CSP400_ASLToText/Python/VideoToFrames.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> dataset = dataset.map(load_video_frames('D:\\CSP400\\CSP400_ASLToText\\Data/dataset\\SL\\a\\01610.mp4'))
#
# File d:\miniconda3\envs\tf\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2202, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2199   if deterministic is not None and not DEBUG_MODE:
#    2200     warnings.warn("The `deterministic` argument has no effect unless the "
#    2201                   "`num_parallel_calls` argument is specified.")
# -> 2202   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2203 else:
#    2204   return ParallelMapDataset(
# ...
